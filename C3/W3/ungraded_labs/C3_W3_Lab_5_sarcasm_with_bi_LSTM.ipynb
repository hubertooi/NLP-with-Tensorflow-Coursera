# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C3/W3/ungraded_labs/C3_W3_Lab_5_sarcasm_with_bi_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Training a Sarcasm Detection Model using Bidirectional LSTMs
#
# In this lab, you will revisit the [News Headlines Dataset for Sarcasm Detection](https://www.kaggle.com/rmisra/news-headlines-dataset-for-sarcasm-detection/home) dataset and use it to train a Bi-LSTM Model.

# %% [markdown]
# ## Download the Dataset
#
# First, you will download the JSON file and extract the contents into lists.

# %%
# Download the dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Out:
# --2022-12-24 17:35:37--  https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.74.128, 173.194.192.128, 172.217.219.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.74.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘sarcasm.json.5’
#
# sarcasm.json.5      100%[===================>]   5.38M  --.-KB/s    in 0.06s
#
# 2022-12-24 17:35:37 (91.2 MB/s) - ‘sarcasm.json.5’ saved [5643545/5643545]

# %%
import json

# Load the JSON file
with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)

# Initialize the lists
sentences = []
labels = []

# Collect sentences and labels into the lists
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %% [markdown]
# ## Split the Dataset
#
# You will then split the lists into train and test sets.

# %%
training_size = 20000

# Split the sentences
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

# Split the labels
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %% [markdown]
# ## Data preprocessing
#
# Next, you will generate the vocabulary and padded sequences.

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(training_labels)
testing_labels = np.array(testing_labels)

# %% [markdown]
# ## Build and Compile the Model
#
# The architecture here is almost identical to the one you used in the previous lab with the IMDB Reviews. Try to tweak the parameters and see how it affects the training time and accuracy (both training and validation).

# %%
import tensorflow as tf

# Parameters
embedding_dim = 16  #original 16
lstm_dim = 32       #original 32
dense_dim = 5      #original 24
dropout_rate = 0.5  #original n/a

# Model Definition with LSTM
model_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_dim,dropout=dropout_rate)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_lstm.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy'])

# Print the model summary
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  bidirectional (Bidirectiona  (None, 64)               12544
#  l)
#
#  dense (Dense)               (None, 5)                 325
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 172,875
# Trainable params: 172,875
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
NUM_EPOCHS = 50 # original 10

# Train the model
history_lstm = model_lstm.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/50
# 625/625 [==============================] - 15s 14ms/step - loss: 0.6868 - accuracy: 0.5602 - val_loss: 0.6851 - val_accuracy: 0.5633
# Epoch 2/50
# 625/625 [==============================] - 9s 14ms/step - loss: 0.6859 - accuracy: 0.5603 - val_loss: 0.6851 - val_accuracy: 0.5633
# Epoch 3/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6858 - accuracy: 0.5603 - val_loss: 0.6849 - val_accuracy: 0.5633
# Epoch 4/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6856 - accuracy: 0.5603 - val_loss: 0.6848 - val_accuracy: 0.5633
# Epoch 5/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6854 - accuracy: 0.5603 - val_loss: 0.6846 - val_accuracy: 0.5633
# Epoch 6/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6850 - accuracy: 0.5603 - val_loss: 0.6838 - val_accuracy: 0.5633
# Epoch 7/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6843 - accuracy: 0.5603 - val_loss: 0.6831 - val_accuracy: 0.5633
# Epoch 8/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6835 - accuracy: 0.5603 - val_loss: 0.6823 - val_accuracy: 0.5633
# Epoch 9/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6826 - accuracy: 0.5603 - val_loss: 0.6812 - val_accuracy: 0.5633
# Epoch 10/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6812 - accuracy: 0.5603 - val_loss: 0.6796 - val_accuracy: 0.5633
# Epoch 11/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6793 - accuracy: 0.5603 - val_loss: 0.6772 - val_accuracy: 0.5633
# Epoch 12/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6763 - accuracy: 0.5603 - val_loss: 0.6742 - val_accuracy: 0.5633
# Epoch 13/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6715 - accuracy: 0.5616 - val_loss: 0.6671 - val_accuracy: 0.5633
# Epoch 14/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.6637 - accuracy: 0.5707 - val_loss: 0.6561 - val_accuracy: 0.5764
# Epoch 15/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6484 - accuracy: 0.6090 - val_loss: 0.6345 - val_accuracy: 0.6548
# Epoch 16/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.6205 - accuracy: 0.6616 - val_loss: 0.6271 - val_accuracy: 0.6442
# Epoch 17/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.5836 - accuracy: 0.6983 - val_loss: 0.5575 - val_accuracy: 0.7427
# Epoch 18/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.5450 - accuracy: 0.7230 - val_loss: 0.5187 - val_accuracy: 0.7564
# Epoch 19/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.5126 - accuracy: 0.7467 - val_loss: 0.4979 - val_accuracy: 0.7572
# Epoch 20/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.4898 - accuracy: 0.7624 - val_loss: 0.4736 - val_accuracy: 0.7746
# Epoch 21/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.4675 - accuracy: 0.7781 - val_loss: 0.4538 - val_accuracy: 0.7897
# Epoch 22/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.4490 - accuracy: 0.7939 - val_loss: 0.4430 - val_accuracy: 0.7916
# Epoch 23/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.4305 - accuracy: 0.7977 - val_loss: 0.4276 - val_accuracy: 0.8076
# Epoch 24/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.4153 - accuracy: 0.8098 - val_loss: 0.4187 - val_accuracy: 0.8047
# Epoch 25/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.4050 - accuracy: 0.8148 - val_loss: 0.4031 - val_accuracy: 0.8168
# Epoch 26/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.3896 - accuracy: 0.8270 - val_loss: 0.4011 - val_accuracy: 0.8134
# Epoch 27/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.3758 - accuracy: 0.8322 - val_loss: 0.3947 - val_accuracy: 0.8168
# Epoch 28/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3637 - accuracy: 0.8394 - val_loss: 0.3778 - val_accuracy: 0.8281
# Epoch 29/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.3516 - accuracy: 0.8456 - val_loss: 0.3715 - val_accuracy: 0.8311
# Epoch 30/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.3419 - accuracy: 0.8493 - val_loss: 0.3686 - val_accuracy: 0.8298
# Epoch 31/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3291 - accuracy: 0.8568 - val_loss: 0.3734 - val_accuracy: 0.8298
# Epoch 32/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3198 - accuracy: 0.8622 - val_loss: 0.3596 - val_accuracy: 0.8381
# Epoch 33/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3138 - accuracy: 0.8658 - val_loss: 0.3561 - val_accuracy: 0.8378
# Epoch 34/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.3053 - accuracy: 0.8692 - val_loss: 0.3632 - val_accuracy: 0.8369
# Epoch 35/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2950 - accuracy: 0.8734 - val_loss: 0.3552 - val_accuracy: 0.8429
# Epoch 36/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2903 - accuracy: 0.8771 - val_loss: 0.3575 - val_accuracy: 0.8448
# Epoch 37/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2850 - accuracy: 0.8784 - val_loss: 0.3917 - val_accuracy: 0.8240
# Epoch 38/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2783 - accuracy: 0.8802 - val_loss: 0.3564 - val_accuracy: 0.8420
# Epoch 39/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2678 - accuracy: 0.8886 - val_loss: 0.3636 - val_accuracy: 0.8413
# Epoch 40/50
# 625/625 [==============================] - 9s 14ms/step - loss: 0.2632 - accuracy: 0.8885 - val_loss: 0.3526 - val_accuracy: 0.8451
# Epoch 41/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2611 - accuracy: 0.8923 - val_loss: 0.3631 - val_accuracy: 0.8439
# Epoch 42/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2528 - accuracy: 0.8947 - val_loss: 0.3523 - val_accuracy: 0.8469
# Epoch 43/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2459 - accuracy: 0.8996 - val_loss: 0.3567 - val_accuracy: 0.8498
# Epoch 44/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2460 - accuracy: 0.8972 - val_loss: 0.3691 - val_accuracy: 0.8429
# Epoch 45/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2399 - accuracy: 0.9000 - val_loss: 0.3741 - val_accuracy: 0.8417
# Epoch 46/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2359 - accuracy: 0.9042 - val_loss: 0.3708 - val_accuracy: 0.8425
# Epoch 47/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2293 - accuracy: 0.9064 - val_loss: 0.3954 - val_accuracy: 0.8351
# Epoch 48/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2302 - accuracy: 0.9060 - val_loss: 0.3636 - val_accuracy: 0.8498
# Epoch 49/50
# 625/625 [==============================] - 8s 13ms/step - loss: 0.2228 - accuracy: 0.9081 - val_loss: 0.3945 - val_accuracy: 0.8380
# Epoch 50/50
# 625/625 [==============================] - 8s 12ms/step - loss: 0.2207 - accuracy: 0.9101 - val_loss: 0.3986 - val_accuracy: 0.8356

# %%
import matplotlib.pyplot as plt

# Plot Utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and loss history
plot_graphs(history_lstm, 'accuracy')
plot_graphs(history_lstm, 'loss')
