# %% [markdown]
# <a href="https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/master/C3/W3/ungraded_labs/C3_W3_Lab_6_sarcasm_with_1D_convolutional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Training a Sarcasm Detection Model using a Convolution Layer
#
# You will be doing the same steps here as the previous lab but will be using a convolution layer instead. As usual, try tweaking the parameters and observe how it affects the results.

# %% [markdown]
# ## Download the Dataset

# %%
# Download the dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Out:
# --2022-12-25 13:54:17--  https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.152.128, 142.250.128.128, 142.251.6.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.152.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘sarcasm.json.4’
#
# sarcasm.json.4      100%[===================>]   5.38M  --.-KB/s    in 0.04s
#
# 2022-12-25 13:54:17 (147 MB/s) - ‘sarcasm.json.4’ saved [5643545/5643545]

# %%
import json

# Load the JSON file
with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)

# Initialize the lists
sentences = []
labels = []

# Collect sentences and labels into the lists
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %% [markdown]
# ## Split the Dataset

# %%
training_size = 20000

# Split the sentences
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

# Split the labels
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %% [markdown]
# ## Data preprocessing

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(training_labels)
testing_labels = np.array(testing_labels)

# %% [markdown]
# ## Build and Compile the Model

# %%
import tensorflow as tf

# Parameters
embedding_dim = 16  # original 16
filters = 128       # original 128
kernel_size = 20     # original 5
dense_dim = 6       # original 6

# Model Definition with Conv1D
model_conv = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(filters, kernel_size, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Set the training parameters
model_conv.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy'])

# Print the model summary
model_conv.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  conv1d (Conv1D)             (None, 101, 128)          41088
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 6)                 774
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 201,869
# Trainable params: 201,869
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
NUM_EPOCHS = 50 #original 10

# Train the model
history_conv = model_conv.fit(training_padded, training_labels, epochs=NUM_EPOCHS, validation_data=(testing_padded, testing_labels))
# Out:
# Epoch 1/50
# 625/625 [==============================] - 7s 4ms/step - loss: 0.6857 - accuracy: 0.5601 - val_loss: 0.6840 - val_accuracy: 0.5633
# Epoch 2/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6844 - accuracy: 0.5603 - val_loss: 0.6833 - val_accuracy: 0.5633
# Epoch 3/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6836 - accuracy: 0.5603 - val_loss: 0.6822 - val_accuracy: 0.5633
# Epoch 4/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6823 - accuracy: 0.5603 - val_loss: 0.6809 - val_accuracy: 0.5633
# Epoch 5/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6806 - accuracy: 0.5605 - val_loss: 0.6790 - val_accuracy: 0.5633
# Epoch 6/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6778 - accuracy: 0.5634 - val_loss: 0.6754 - val_accuracy: 0.5765
# Epoch 7/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6730 - accuracy: 0.5774 - val_loss: 0.6685 - val_accuracy: 0.5834
# Epoch 8/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6626 - accuracy: 0.5938 - val_loss: 0.6537 - val_accuracy: 0.6037
# Epoch 9/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6395 - accuracy: 0.6205 - val_loss: 0.6240 - val_accuracy: 0.6941
# Epoch 10/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6002 - accuracy: 0.6867 - val_loss: 0.5827 - val_accuracy: 0.7174
# Epoch 11/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5647 - accuracy: 0.7258 - val_loss: 0.5561 - val_accuracy: 0.7189
# Epoch 12/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.5370 - accuracy: 0.7394 - val_loss: 0.5296 - val_accuracy: 0.7353
# Epoch 13/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.5102 - accuracy: 0.7541 - val_loss: 0.5031 - val_accuracy: 0.7536
# Epoch 14/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4849 - accuracy: 0.7705 - val_loss: 0.4813 - val_accuracy: 0.7645
# Epoch 15/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4586 - accuracy: 0.7854 - val_loss: 0.4567 - val_accuracy: 0.7831
# Epoch 16/50
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4328 - accuracy: 0.8031 - val_loss: 0.4411 - val_accuracy: 0.7906
# Epoch 17/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4079 - accuracy: 0.8156 - val_loss: 0.4156 - val_accuracy: 0.8053
# Epoch 18/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3837 - accuracy: 0.8311 - val_loss: 0.4134 - val_accuracy: 0.8032
# Epoch 19/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3610 - accuracy: 0.8433 - val_loss: 0.3909 - val_accuracy: 0.8173
# Epoch 20/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3391 - accuracy: 0.8542 - val_loss: 0.3878 - val_accuracy: 0.8198
# Epoch 21/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3189 - accuracy: 0.8668 - val_loss: 0.3762 - val_accuracy: 0.8249
# Epoch 22/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3016 - accuracy: 0.8750 - val_loss: 0.3635 - val_accuracy: 0.8319
# Epoch 23/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2842 - accuracy: 0.8824 - val_loss: 0.3608 - val_accuracy: 0.8353
# Epoch 24/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2680 - accuracy: 0.8905 - val_loss: 0.3522 - val_accuracy: 0.8444
# Epoch 25/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2531 - accuracy: 0.8981 - val_loss: 0.3595 - val_accuracy: 0.8383
# Epoch 26/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2372 - accuracy: 0.9053 - val_loss: 0.3479 - val_accuracy: 0.8469
# Epoch 27/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2243 - accuracy: 0.9110 - val_loss: 0.3520 - val_accuracy: 0.8453
# Epoch 28/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.2108 - accuracy: 0.9190 - val_loss: 0.3540 - val_accuracy: 0.8490
# Epoch 29/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1979 - accuracy: 0.9234 - val_loss: 0.3536 - val_accuracy: 0.8486
# Epoch 30/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1857 - accuracy: 0.9311 - val_loss: 0.3566 - val_accuracy: 0.8462
# Epoch 31/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1753 - accuracy: 0.9331 - val_loss: 0.3861 - val_accuracy: 0.8375
# Epoch 32/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1630 - accuracy: 0.9402 - val_loss: 0.4040 - val_accuracy: 0.8372
# Epoch 33/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1513 - accuracy: 0.9471 - val_loss: 0.3978 - val_accuracy: 0.8422
# Epoch 34/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1422 - accuracy: 0.9497 - val_loss: 0.4310 - val_accuracy: 0.8372
# Epoch 35/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1320 - accuracy: 0.9534 - val_loss: 0.4046 - val_accuracy: 0.8432
# Epoch 36/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1217 - accuracy: 0.9585 - val_loss: 0.3949 - val_accuracy: 0.8481
# Epoch 37/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1135 - accuracy: 0.9620 - val_loss: 0.4089 - val_accuracy: 0.8514
# Epoch 38/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1049 - accuracy: 0.9654 - val_loss: 0.4179 - val_accuracy: 0.8499
# Epoch 39/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0952 - accuracy: 0.9698 - val_loss: 0.4337 - val_accuracy: 0.8512
# Epoch 40/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0901 - accuracy: 0.9707 - val_loss: 0.4361 - val_accuracy: 0.8493
# Epoch 41/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0810 - accuracy: 0.9764 - val_loss: 0.4527 - val_accuracy: 0.8486
# Epoch 42/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0723 - accuracy: 0.9791 - val_loss: 0.4884 - val_accuracy: 0.8413
# Epoch 43/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0668 - accuracy: 0.9815 - val_loss: 0.4770 - val_accuracy: 0.8489
# Epoch 44/50
# 625/625 [==============================] - 3s 5ms/step - loss: 0.0591 - accuracy: 0.9851 - val_loss: 0.4882 - val_accuracy: 0.8483
# Epoch 45/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0544 - accuracy: 0.9863 - val_loss: 0.5476 - val_accuracy: 0.8378
# Epoch 46/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0482 - accuracy: 0.9886 - val_loss: 0.5144 - val_accuracy: 0.8480
# Epoch 47/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0456 - accuracy: 0.9893 - val_loss: 0.5282 - val_accuracy: 0.8471
# Epoch 48/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0403 - accuracy: 0.9911 - val_loss: 0.5335 - val_accuracy: 0.8480
# Epoch 49/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0370 - accuracy: 0.9925 - val_loss: 0.5531 - val_accuracy: 0.8490
# Epoch 50/50
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0329 - accuracy: 0.9937 - val_loss: 0.6033 - val_accuracy: 0.8389

# %%
import matplotlib.pyplot as plt

# Plot Utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and loss history
plot_graphs(history_conv, 'accuracy')
plot_graphs(history_conv, 'loss')
